# %%
MY_DHE = "0123456789abcdefghijklmnopqrstuvwxyz"
MY = {}
for i in range(len(MY_DHE)):
    MY[MY_DHE[i]] = i
def MY_to_int(MYZ,K = 36):
    MYZ = str(MYZ)
    INT = 0
    while len(MYZ):
        INT += MY[MYZ[0]]*(K**(len(MYZ)-1))
        MYZ = MYZ[1:]
    return INT
def int_to_MY(INT,K = 36):
    INT = int(INT)
    MYZ = ""
    while INT:
        MYZ = MY_DHE[INT%K]+MYZ
        INT = INT//K
    return MYZ
def name_to_information(name):
    return name[0],MY_to_int(name[1:4]),MY_to_int(name[4:])
def to_dec(hex_n):
    return MY_to_int(hex_n)

# %%
name_to_information("Sbeb3a3")
# Out:
# ('S', 14771, 4251)

# %%
def find_max_min(list_for_find):
    new_list = []
    for i in list_for_find:
        new_list.append(MY_to_int(i))
    return [[max(new_list),int_to_MY(max(new_list))],[min(new_list),int_to_MY(min(new_list))]],len(new_list)

# %%
find_max_min(['1yj', '1xl', '1xf'])
# Out:
# ([[2539, '1yj'], [2499, '1xf']], 3)

# %%
with open("ALL_LIST.txt","r") as f:
    ALL_LIST = eval(f.read())

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(ALL_LIST[0],label="J")
plt.plot(ALL_LIST[1],label="R")
plt.plot(ALL_LIST[2],label="S")
plt.legend()
plt.ylabel("total_number")
plt.xlabel("time")
plt.savefig("1e4.jpg")

# %%
plt.plot(ALL_LIST[3])
plt.show()

# %%
with open("DFE_LEN.txt","r") as f:
    LEN = eval(f.read())
# Out:
# Traceback (most recent call last):
#
#   File "d:\001-python\python3.9\lib\site-packages\IPython\core\interactiveshell.py", line 3418, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#
#   File "<ipython-input-11-12a18eb58834>", line 2, in <module>
#     LEN = eval(f.read())
#
#   File "<string>", line unknown
#
#     ^
# SyntaxError: unexpected EOF while parsing

# %%
plt.plot(LEN)
plt.show()

# %%
with open("FIGHT_MESSAGE.txt","r") as f:
    FIGHT_MESSAGE = eval(f.read())

# %%
FIGHT_MESSAGE

# %%
for i in BIGBOOK_FIGHT["Jtuep1z"]:
    try:
        print(FIGHT_MESSAGE[f'Jtuep1z><{i}'])
    except:
        print(FIGHT_MESSAGE[f'{i}><Jtuep1z'])

# %%
with open("BIGBOOK_FIGHT.txt","r") as f:
    BIGBOOK_FIGHT = eval(f.read())

# %%
BIGBOOK_FIGHT["Jtuep1z"]
